# %%
import requests
from PIL import Image
from io import BytesIO #use to handle image data as a stream  of bytes

# Securely store your API token (replace with your new token)
API_KEY = "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"  # Replace with your actual key

# Define the Hugging Face API URL to generate image
API_URL = "https://api-inference.huggingface.co/models/runwayml/stable-diffusion-v1-5"
#API send the propmt to hugging face stable diffusion model , using request library

# Define the image generation prompt
payload = {"inputs": "A futuristic cyberpunk city with neon lights and flying cars, ultra-detailed, 4K"}

# Set authentication headers
headers = {"Authorization": f"Bearer {API_KEY}"}

# Send request to Hugging Face API
response = requests.post(API_URL, headers=headers, json=payload)

# Process the response
if response.status_code == 200:
    image = Image.open(BytesIO(response.content))

    # Save and display the generated image
    image.save("huggingface_generated.png")  #Recieve and process the generated image data and saves it into PNG
    image.show()
    print("Image saved as huggingface_generated.png")
else:
    print("Error:", response.text)
# Out:
# Error: {"error":"Model stable-diffusion-v1-5/stable-diffusion-v1-5 is currently loading","estimated_time":945.1328125}
